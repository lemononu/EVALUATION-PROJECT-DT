# %%
#import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# we have imported the necessary libraries

# %%
#uploading dataset
df=pd.read_csv('baseball.csv')
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %% [markdown]
# So the given independent features are as follows:- R-runs,AB-at bat,H-hit,2B-double,3B-triple,HR-home runs,BB-base on balls,SO-strike out,SB-stolen base,RA-run average,ER- earned run,ERA-earned run average,CG-complete game,SHO-shutout,SV-save,E-errors and the output variable is W-Number of predicted wins .

# %%
df.shape
# Out:
# (30, 17)

# %% [markdown]
# There are 30 rows and 17 columns present inside dataset.

# %%
# Data Analysis and Visualization
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# This column shows the statistical values for the data like mean,standard deviation and percentiles,minimum and maximum.

# %%
#checking for missing values
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# There are no null or missing values in the above dataset.
#
# We can also see this by a visualization method by using seaborn library.

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# It is observed that data has integer and float datatypes.

# %%
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %% [markdown]
# from the above code we have observe the corelation between the features.

# %%
sns.heatmap(df.corr(),annot=True,fmt='.1g')
# Out:
# <AxesSubplot:>

# %% [markdown]
# This heatmap shows the correlation of features with each other. This shows how much a independent feature or variable is contributing to the output, i.e. positively corelated or negatively correlated. There exist a multicolinearity in 'AB and H'.

# %%
sns.catplot(x='W',y='R',data=df)

# %% [markdown]
# we can observe that as the number of runs increases so the winning value also increases that shows that runs and wins are proportional to each other and shows positive correaltion.

# %%
sns.catplot(x='W',y='AB',data=df)

# %% [markdown]
# from this plot we can observe that tha data is not normally distirbuted and may be some outliers are present inside it.

# %%
sns.catplot(x='W',y='H',data=df)

# %% [markdown]
# from this plot we can observe that tha data is not normally distirbuted not correalted and may be some of the outliers are present inside it.

# %%
sns.catplot(x='W',y='2B',data=df)

# %% [markdown]
# we can observe that as the number of doubles increases so the winning value also increases that shows that doubles and wins are proportional to each other and shows positive correaltion with each other.

# %%
sns.catplot(x='W',y='3B',data=df)

# %% [markdown]
# from this plot we can observe that tha data distribution is not in aproper manner that is not normally distributed and not correalted and some of the outliers are present inside it.

# %%
sns.catplot(x='W',y='BB',data=df)

# %% [markdown]
# base on balls shows a postived corealtion with the winning value so it is a positively corelated feature.

# %%
sns.catplot(x='W',y='HR',data=df)

# %% [markdown]
# we can observe that as the number of home runs increases so the winning value also increases that shows that home runs and wins are proportional to each other and shows positive correaltion.

# %%
sns.distplot(df['R'])
# Out:
# <AxesSubplot:xlabel='R', ylabel='Density'>

# %% [markdown]
# so the above distplot is also used to observe the skewness and distribution of data so we have checked skewness using distplot and we can see that data is not normally distributed in the above plot.

# %%
sns.distplot(df['AB'])
# Out:
# <AxesSubplot:xlabel='AB', ylabel='Density'>

# %% [markdown]
# Little bit of skewness is present so it can be ignored.

# %%
sns.distplot(df['H'])
# Out:
# <AxesSubplot:xlabel='H', ylabel='Density'>

# %% [markdown]
# so in this plot we can observe skewness is present in Hit feature.

# %%
sns.distplot(df['2B'])
# Out:
# <AxesSubplot:xlabel='2B', ylabel='Density'>

# %% [markdown]
# we can say this a normally distributed data with very less skewness.

# %%
sns.distplot(df['3B'])
# Out:
# <AxesSubplot:xlabel='3B', ylabel='Density'>

# %% [markdown]
# It is a normally distirbuted data.

# %% [markdown]
# so we can see all the features in a single window to observe that skewness is present or not.

# %%
sns.pairplot(df,kind='scatter')

# %% [markdown]
# As we can see from the above pairplot, data are not normally distirbuted and skewness is present and some outliers may be present inside the dataset.so to remove skewness of data we will use power transform function.

# %%
#checking skewness
df.plot(kind='density',subplots=True,layout=(7,3),sharex=False,legend=False)
plt.show()

# %% [markdown]
# from the plot, we can observe that there is skewness present in dataset, data are not normally distributed so we need to remove skewness using power transform function.

# %%
#splitting data into independent variable and target variable
x=df.iloc[:,1:-1]
x
# Out:
#       R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  SV
# 0   724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8  56
# 1   696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12  45
# 2   669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10  38
# 3   622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9  37
# 4   689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12  35
# 5   891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7   10  34
# 6   764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3    4  48
# 7   713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0   10  43
# 8   644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1   12  60
# 9   748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3   10  40
# 10  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5    9  45
# ...

# %%
y=df.iloc[:,0]

# %%
y
# Out:
# 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 5      93
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: W, dtype: int64

# %%
from scipy.stats import skew
x.skew().sort_values(ascending=True)
# Out:
# 2B    -0.230650
# SO    -0.156065
# RA     0.045734
# ERA    0.053331
# ER     0.058710
# 3B     0.129502
# BB     0.158498
# AB     0.183437
# SB     0.479893
# HR     0.516441
# SHO    0.565790
# SV     0.657524
# H      0.670254
# CG     0.736845
# R      1.200786
# dtype: float64

# %%
from sklearn.preprocessing import power_transform
x_new=power_transform(x)
type(x_new)
# Out:
# numpy.ndarray

# %%
x=pd.DataFrame(x_new,columns=x.columns)
x
# Out:
#       R   AB    H        2B        3B        HR        BB        SO        SB  \
# 0   0.0  0.0  0.0  1.477685  1.033103 -0.764626 -1.610915 -2.569896  0.939708
# 1   0.0  0.0  0.0  0.084269  1.203320 -0.158581 -0.502749  0.134913 -0.539693
# 2   0.0  0.0  0.0  1.670782 -0.160270 -0.689676  1.128294 -0.901254  0.211956
# 3   0.0  0.0  0.0 -0.848600 -0.360521 -0.879049 -1.181207 -0.189628 -0.642564
# 4   0.0  0.0  0.0  0.792183  1.616444 -0.329850 -0.206771  0.085459  0.079629
# 5   0.0  0.0  0.0  1.998506 -1.461062  1.937860  1.708067 -0.957960  0.298238
# 6   0.0  0.0  0.0 -0.198558 -1.224911  1.460099  1.461121 -0.228668 -0.910154
# 7   0.0  0.0  0.0 -1.556454 -1.110302  1.583551 -0.904450  0.807174 -2.102897
# 8   0.0  0.0  0.0  0.141687  0.130611  0.200058 -0.559191  0.594561  0.255285
# 9   0.0  0.0  0.0  1.099405  0.225256  0.007404  0.204599 -0.986257 -0.489090
# 10  0.0  0.0  0.0  0.199390  0.130611  0.355503  0.634349 -0.170084  0.825451
# ...

# %%
x.shape
# Out:
# (30, 15)

# %%
x.skew().sort_values(ascending=True)
# Out:
# 3B    -0.072933
# CG    -0.059785
# 2B    -0.035315
# SB    -0.010455
# RA    -0.008082
# BB    -0.007760
# ER    -0.001940
# HR    -0.000065
# R      0.000000
# AB     0.000000
# H      0.000000
# SV     0.000836
# ERA    0.001746
# SHO    0.006560
# SO     0.041170
# dtype: float64

# %%
nw=x.skew()
nw
# Out:
# R      0.000000
# AB     0.000000
# H      0.000000
# 2B    -0.035315
# 3B    -0.072933
# HR    -0.000065
# BB    -0.007760
# SO     0.041170
# SB    -0.010455
# RA    -0.008082
# ER    -0.001940
# ERA    0.001746
# CG    -0.059785
# SHO    0.006560
# SV     0.000836
# dtype: float64

# %% [markdown]
# so we have removed the skewness from the data.

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
#CHECKING OUTLIERS
plt.boxplot(df['H'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14c928f40>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x14c97e640>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x14c928be0>],
#  'medians': [<matplotlib.lines.Line2D at 0x14c97ed00>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14c98d0a0>],
#  'means': []}

# %%
plt.boxplot(df['R'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14c9d7e20>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x14c9e6520>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x14c9d7ac0>],
#  'medians': [<matplotlib.lines.Line2D at 0x14c9e6be0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14c9e6f40>],
#  'means': []}

# %%
plt.boxplot(df['AB'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14cab37c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x14cab3e80>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x14cab3460>],
#  'medians': [<matplotlib.lines.Line2D at 0x14cac0580>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14cac08e0>],
#  'means': []}

# %%
plt.boxplot(df['2B'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14cb86be0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x14cb922e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x14cb86880>],
#  'medians': [<matplotlib.lines.Line2D at 0x14cb929a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14cb92d00>],
#  'means': []}

# %%
plt.boxplot(df['3B'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14cc05ac0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x14cc6d1c0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x14cc05760>],
#  'medians': [<matplotlib.lines.Line2D at 0x14cc6d880>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14cc6dbe0>],
#  'means': []}

# %%
plt.boxplot(df['HR'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14cd379a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x14cd450a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x14cd37640>],
#  'medians': [<matplotlib.lines.Line2D at 0x14cd45760>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14cd45ac0>],
#  'means': []}

# %%
plt.boxplot(df['BB'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14ce13340>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x14ce13a00>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x14cdaafa0>],
#  'medians': [<matplotlib.lines.Line2D at 0x14ce1e100>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14ce1e460>],
#  'means': []}

# %%
plt.boxplot(df['SO'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14cee87c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x14cee8e80>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x14cee8460>],
#  'medians': [<matplotlib.lines.Line2D at 0x14cef4580>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14cef48e0>],
#  'means': []}

# %%
plt.boxplot(df['SB'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14cfb9be0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x14cfc62e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x14cfb9880>],
#  'medians': [<matplotlib.lines.Line2D at 0x14cfc69a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14cfc6d00>],
#  'means': []}

# %%
plt.boxplot(df['RA'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14d08eaf0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x14d09a1f0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x14d08e790>],
#  'medians': [<matplotlib.lines.Line2D at 0x14d09a8b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14d09ac10>],
#  'means': []}

# %%
plt.boxplot(df['ER'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14d16a490>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x14d16ab50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x14d16a130>],
#  'medians': [<matplotlib.lines.Line2D at 0x14d173250>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14d1735b0>],
#  'means': []}

# %%
plt.boxplot(df['ERA'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14d234e50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x14d244550>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x14d234af0>],
#  'medians': [<matplotlib.lines.Line2D at 0x14d244c10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14d244f70>],
#  'means': []}

# %%
plt.boxplot(df['CG'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14d2b3250>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x14d2b3910>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x14d2a4eb0>],
#  'medians': [<matplotlib.lines.Line2D at 0x14d2b3fd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14d31a370>],
#  'means': []}

# %%
plt.boxplot(df['SHO'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14d3d8ac0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x14d3e51c0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x14d3d8760>],
#  'medians': [<matplotlib.lines.Line2D at 0x14d3e5880>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14d3e5be0>],
#  'means': []}

# %%
plt.boxplot(df['SV'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14d44f820>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x14d44fee0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x14d44f4c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x14d45e5e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14d45e940>],
#  'means': []}

# %%
plt.boxplot(df['E'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14d586580>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x14d586c70>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x14d586220>],
#  'medians': [<matplotlib.lines.Line2D at 0x14d591370>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14d5916d0>],
#  'means': []}

# %% [markdown]
# So from the above boxplots we have cocluded that there are very less number of outliers are present insdie the data set so no need to remove outliers .

# %%
#LABEL ENCODING
y=df['W'].apply(lambda y_value:1 if y_value>=80 else 0)
y
# Out:
# 0     1
# 1     1
# 2     1
# 3     0
# 4     0
# 5     1
# 6     1
# 7     1
# 8     1
# 9     0
# 10    1
# 11    1
# 12    1
# 13    0
# 14    0
# 15    1
# 16    1
# 17    1
# 18    0
# 19    0
# 20    1
# 21    1
# 22    0
# 23    0
# 24    0
# 25    1
# 26    1
# 27    0
# 28    0
# 29    0
# Name: W, dtype: int64

# %% [markdown]
# so the winning values greater than 80 we consdiered as 1 and below 80 as 0.

# %%
y.shape
# Out:
# (30,)

# %%
x.shape
# Out:
# (30, 15)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def var_calc():
    vif=pd.DataFrame()
    vif['VIF Factor']=[variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
    vif['features']=x.columns
    print(vif)

# %%
var_calc()
# Out:
#     VIF Factor features
# 0          NaN        R
# 1          NaN       AB
# 2          NaN        H
# 3     2.220912       2B
# 4     2.693000       3B
# 5     2.864776       HR
# 6     3.264811       BB
# 7     2.309984       SO
# 8     1.884150       SB
# 9   150.696674       RA
# 10  542.263168       ER
# 11  298.289953      ERA
# 12    2.132218       CG
# 13    3.182749      SHO
# 14    3.435155       SV

# %%
#training and testing of model
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=.20,random_state=147)

# %%
xtrain.shape
# Out:
# (24, 15)

# %%
ytrain.shape
# Out:
# (24,)

# %%
xtest.shape
# Out:
# (6, 15)

# %%
ytest.shape
# Out:
# (6,)

# %%
#APPLYING ML ALGORITHMS
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix,classification_report
#LogisticRegression
lg=LogisticRegression()
lg.fit(xtrain,ytrain)
predlg=lg.predict(xtest)
print(accuracy_score(ytest,predlg))
print(classification_report(ytest,predlg))
print(confusion_matrix(ytest,predlg))
# Out:
# 0.5
#               precision    recall  f1-score   support
#
#            0       0.33      0.50      0.40         2
#            1       0.67      0.50      0.57         4
#
#     accuracy                           0.50         6
#    macro avg       0.50      0.50      0.49         6
# weighted avg       0.56      0.50      0.51         6
#
# [[1 1]
#  [2 2]]

# %%
#RandomForestClassifier
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()
rfc.fit(xtrain,ytrain)
predrfc=rfc.predict(xtest)
print(accuracy_score(ytest,predrfc))
print(classification_report(ytest,predrfc))
print(confusion_matrix(ytest,predrfc))
# Out:
# 0.8333333333333334
#               precision    recall  f1-score   support
#
#            0       1.00      0.50      0.67         2
#            1       0.80      1.00      0.89         4
#
#     accuracy                           0.83         6
#    macro avg       0.90      0.75      0.78         6
# weighted avg       0.87      0.83      0.81         6
#
# [[1 1]
#  [0 4]]

# %%
#SUPPORT VECTOR CLASSIFIER
from sklearn.svm import SVC
svc=SVC()
svc.fit(xtrain,ytrain)
predsvc=svc.predict(xtest)
print(accuracy_score(ytest,predsvc))
print(classification_report(ytest,predsvc))
print(confusion_matrix(ytest,predsvc))
# Out:
# 0.6666666666666666
#               precision    recall  f1-score   support
#
#            0       0.50      0.50      0.50         2
#            1       0.75      0.75      0.75         4
#
#     accuracy                           0.67         6
#    macro avg       0.62      0.62      0.62         6
# weighted avg       0.67      0.67      0.67         6
#
# [[1 1]
#  [1 3]]

# %%
#GaussianNB
from sklearn.naive_bayes import GaussianNB
gnb=GaussianNB()
gnb.fit(xtrain,ytrain)
gnb.score(xtrain,ytrain)
predgnb=gnb.predict(xtest)
print(accuracy_score(ytest,predgnb))
print(confusion_matrix(ytest,predgnb))
print(classification_report(ytest,predgnb))
# Out:
# 1.0
# [[2 0]
#  [0 4]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       1.00      1.00      1.00         4
#
#     accuracy                           1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6

# %%
from sklearn.tree import DecisionTreeClassifier
#DecisionTreeClassifier
dtc=DecisionTreeClassifier()
dtc.fit(xtrain,ytrain)
dtc.score(xtrain,ytrain)
preddtc=dtc.predict(xtest)
print(accuracy_score(ytest,preddtc))
print(confusion_matrix(ytest,preddtc))
print(classification_report(ytest,preddtc))
# Out:
# 0.8333333333333334
# [[1 1]
#  [0 4]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.50      0.67         2
#            1       0.80      1.00      0.89         4
#
#     accuracy                           0.83         6
#    macro avg       0.90      0.75      0.78         6
# weighted avg       0.87      0.83      0.81         6

# %% [markdown]
# Among all the algorithms Gaussian NB gives the highest accuracy of 100%. so we will go with Gaussian NB algorithm.

# %%
# CROSS VALIDATION
from sklearn.model_selection import cross_val_score
scr=cross_val_score(lg,x,y,cv=5)
print('cross validation score of logistic regression is',scr.mean())
# Out:
# cross validation score of logistic regression is 0.8666666666666666

# %%
scr2=cross_val_score(rfc,x,y,cv=5)
print('cross validation score of Random forest classifier is',scr2.mean())
# Out:
# cross validation score of Random forest classifier is 0.8333333333333334

# %%
scr3=cross_val_score(svc,x,y,cv=5)
print('cross validation score of Support vector classifier is',scr3.mean())
# Out:
# cross validation score of Support vector classifier is 0.8666666666666666

# %%
scr4=cross_val_score(gnb,x,y,cv=5)
print('cross validation score of Decision Tree classifier is',scr4.mean())
# Out:
# cross validation score of Decision Tree classifier is 0.8666666666666668

# %%
scr5=cross_val_score(rfc,x,y,cv=5)
print('cross validation score of Gaussian NB is',scr5.mean())
# Out:
# cross validation score of Gaussian NB is 0.8333333333333334

# %% [markdown]
# Logistic Regression is performing better among all so we will proceed with Logistic Regression.

# %%
# HYPERPARAMETER TUNING
RandomForestClassifier()
parameters={'max_features':["auto", "sqrt", "log2"],'max_depth':[4,5,6,7,8],'criterion':["gini", "entropy"]}

# %%
from sklearn.model_selection import GridSearchCV
gcv=GridSearchCV(RandomForestClassifier(),parameters,cv=5,scoring='accuracy')
gcv.fit(xtrain,ytrain)
gcv.best_params_ #printing the best parameters found by GridSearchCV
# Out:
# {'criterion': 'gini', 'max_depth': 4, 'max_features': 'auto'}

# %%
gcv_pred=gcv.best_estimator_.predict(xtest)
accuracy_score(ytest,gcv_pred)
# Out:
# 0.8333333333333334

# %%
#ROC AUC PLOT
from sklearn.metrics import plot_roc_curve
plot_roc_curve(gcv.best_estimator_,xtest,ytest)
plt.title('ROC-AUC Curve')
plt.show()

# %% [markdown]
# AUC score is 100%,so it is the best score.

# %%
#SAVING THE BEST MODEL
import joblib
joblib.dump(gcv.best_estimator_,'baseball-csv.pk1')
# Out:
# ['baseball-csv.pk1']
