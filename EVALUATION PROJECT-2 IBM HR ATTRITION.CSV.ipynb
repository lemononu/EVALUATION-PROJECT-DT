# %%
#IMPORT REQUIRED LIBRARIES
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# We have imported the required libraries.

# %%
# LOADING THE DATASET
df=pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# So we have dataset in which there are 1470 rows and 35 columns.

# %%
df.head(5)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.shape
# Out:
# (1470, 35)

# %%
# Data Analysis and Visualization
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# This column shows the statistical values for the numerical data like mean,standard deviation and percentiles,minimum and maximum.

# %%
#checking for missing values
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# There are no null or missing values in the above dataset.
#
# We can also see this by a visualization method by using seaborn library.

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %% [markdown]
# It is observed that data has integer and object/categorical datatype only.

# %%
df.corr()
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeCount                  NaN        NaN               NaN        NaN
# EmployeeNumber           -0.010145  -0.050990          0.032916   0.042070
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# ...

# %%
sns.heatmap(df.corr(),annot=True,fmt='.1g')
# Out:
# <AxesSubplot:>

# %% [markdown]
# we are unable to identify the correlation in the above heatmap so we will observe the corretaltion with independent variables and target variables.

# %%
corr_mat=df.corr()
#size of the canvas
plt.figure(figsize=[20,20])
#plt the correlation matrix
sns.heatmap(corr_mat,annot=True)
plt.title('Correaltion Matrix')
plt.show()

# %% [markdown]
# This heatmap shows the correlation of features with each other. This shows how much a independent feature or variable is contributing to the output, i.e. positively corelated or negatively correlated. There exist a multicolinearity inside the dataset.

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
sns.set_style('darkgrid')
sns.countplot(x='Department',data=df)
# Out:
# <AxesSubplot:xlabel='Department', ylabel='count'>

# %% [markdown]
# From the above plot we can observe that the IBM has three departments and value count for people is shown below-
#
# Sales-410 employees approximately
#
# R&D-950 employees approximately
#
# HR- 50 employees approximately

# %%
sns.set_style('darkgrid')
sns.countplot(x='BusinessTravel',data=df)
# Out:
# <AxesSubplot:xlabel='BusinessTravel', ylabel='count'>

# %% [markdown]
# This plot shows the travel history of employees who travels regularly and frequently and not travel either.
#
# Travel rarely around 1025 employees
#
# Travel frequently business travel around 250 employees
#
# Do not travel around 170 employees

# %%
sns.set_style('darkgrid')
sns.countplot(x='EducationField',data=df)
# Out:
# <AxesSubplot:xlabel='EducationField', ylabel='count'>

# %% [markdown]
# This plot gives us the infortmation regarding the different educational fields employess are working i.e. life sciences,medical,technical,human resource etc.

# %%
sns.set_style('darkgrid')
sns.countplot(x='Gender',data=df)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %% [markdown]
# This graph shows tha value count for male and female inside the company.
#
# male-950 approx.
#
# female-590 approx.

# %%
sns.set_style('darkgrid')
sns.countplot(x='JobRole',data=df,orient='h')
plt.figure(figsize=[10,10])
plt.show()

# %% [markdown]
# from the above plot we can observe the value count of employees in each department.

# %%
sns.set_style('darkgrid')
sns.countplot(x='MaritalStatus',data=df)
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='count'>

# %% [markdown]
# This plot provides the marital status of the employees in the company.for ex-approximately 470 people are single,670 people are married and around 310 people are divorced.

# %%
sns.set_style('darkgrid')
sns.countplot(x='OverTime',data=df)
# Out:
# <AxesSubplot:xlabel='OverTime', ylabel='count'>

# %% [markdown]
# above graph shows overtime value count for employees around 410 people work overtime and around 1100 people do not do overtime.

# %%
sns.set_style('darkgrid')
sns.countplot(x='Attrition',hue='Department',data=df)
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %% [markdown]
# So this plot is between the target variable (Attrition) and independent variable(Department) in terms of attrition.

# %%
sns.set_style('darkgrid')
sns.countplot(x='Attrition',hue='BusinessTravel',data=df)
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %%
sns.set_style('darkgrid')
sns.countplot(x='Attrition',hue='EducationField',data=df)
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %%
sns.set_style('darkgrid')
sns.countplot(x='Attrition',hue='Gender',data=df)
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %% [markdown]
# This plot show the attrition effects on the gender value count that around 90 females have left/terminated and aorund 150 males left/terminated from organization.

# %%
sns.set_style('darkgrid')
sns.countplot(x='Attrition',hue='JobRole',data=df)
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %% [markdown]
# this plot shows the attrition value count for employees in each job role people who left or terminated from the jobs from various job roles.

# %%
sns.set_style('darkgrid')
sns.countplot(x='Attrition',hue='MaritalStatus',data=df)
# Out:
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %% [markdown]
# from the above plot we can observe the attrition effects on the employees having marital status as divoreced,single and married.

# %%
sns.distplot(df['Age'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# This graph shows the value count of employees in the age of between 20-55.most of the employees are in the range of 28-42.there is some skewness inside data.

# %%
sns.distplot(df['DailyRate'])
# Out:
# <AxesSubplot:xlabel='DailyRate', ylabel='Density'>

# %% [markdown]
# This plot shows the daily rate of employess in the organization which ranges between 100-1500. also we can say that data is not normally distributed.

# %%
sns.distplot(df['DistanceFromHome'])
# Out:
# <AxesSubplot:xlabel='DistanceFromHome', ylabel='Density'>

# %% [markdown]
# from the above plot we can observe skewness inside the data data is not distributed normally.

# %%
sns.distplot(df['Education'])
# Out:
# <AxesSubplot:xlabel='Education', ylabel='Density'>

# %% [markdown]
# from the above plot we can observe skewness inside the data data is not distributed normally.

# %%
sns.distplot(df['HourlyRate'])
# Out:
# <AxesSubplot:xlabel='HourlyRate', ylabel='Density'>

# %% [markdown]
# from the above plot we can observe skewness inside the data data is not distributed normally.

# %%
# LABEL ENCODING
from sklearn.preprocessing import LabelEncoder
lencode=LabelEncoder()
df['Attrition']=lencode.fit_transform(df['Attrition'])
df['BusinessTravel']=lencode.fit_transform(df['BusinessTravel'])
df['Department']=lencode.fit_transform(df['Department'])
df['EducationField']=lencode.fit_transform(df['EducationField'])
df['Gender']=lencode.fit_transform(df['Gender'])
df['JobRole']=lencode.fit_transform(df['JobRole'])
df['MaritalStatus']=lencode.fit_transform(df['MaritalStatus'])
df['Over18']=lencode.fit_transform(df['Over18'])
df['OverTime']=lencode.fit_transform(df['OverTime'])

# %%
df
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41          1               2       1102           2                 1
# 1      49          0               1        279           1                 8
# 2      37          1               2       1373           1                 2
# 3      33          0               1       1392           1                 3
# 4      27          0               2        591           1                 2
# ...   ...        ...             ...        ...         ...               ...
# 1465   36          0               1        884           1                23
# 1466   39          0               2        613           1                 6
# 1467   27          0               2        155           1                 4
# 1468   49          0               1       1023           2                 2
# 1469   34          0               2        628           1                 8
#
# ...

# %%
#CHECKING OUTLIERS
plt.boxplot(df['Age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x123216b50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x123223250>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1232167f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x123223910>],
#  'fliers': [<matplotlib.lines.Line2D at 0x123223c70>],
#  'means': []}

# %% [markdown]
# No outliers present

# %%
plt.boxplot(df['DailyRate'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1232cda00>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1232dc100>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1232cd6a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1232dc7c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1232dcb20>],
#  'means': []}

# %% [markdown]
# no outliers present.

# %%
plt.boxplot(df['Education'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x123249340>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1232ed190>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1232f5e50>],
#  'medians': [<matplotlib.lines.Line2D at 0x1232fc310>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1232fc730>],
#  'means': []}

# %% [markdown]
# no outliers present.

# %%
plt.boxplot(df['MonthlyIncome'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1233eeac0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1234721c0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1233ee760>],
#  'medians': [<matplotlib.lines.Line2D at 0x123472880>],
#  'fliers': [<matplotlib.lines.Line2D at 0x123472be0>],
#  'means': []}

# %% [markdown]
# we can observe some outliers lies in the monthly income column.

# %% [markdown]
# there are 30 columns in dataset so it is not possible to plot each and every columns seperately or we can plot all together also.

# %%
#plotting boxplot for first 15 columns
df.iloc[:,0:15].boxplot(figsize=[20,10])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
#plotting boxplot for second 18 columns
df.iloc[:,15:].boxplot(figsize=[20,10])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
#Splitting the independent variables and target
x=df.drop('Attrition',axis=1)
x
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0      41               2       1102           2                 1          2
# 1      49               1        279           1                 8          1
# 2      37               2       1373           1                 2          2
# 3      33               1       1392           1                 3          4
# 4      27               2        591           1                 2          1
# ...   ...             ...        ...         ...               ...        ...
# 1465   36               1        884           1                23          2
# 1466   39               2        613           1                 6          1
# 1467   27               2        155           1                 4          3
# 1468   49               1       1023           2                 2          3
# 1469   34               2        628           1                 8          3
#
# ...

# %%
y=df.iloc[:,1]

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 1465    0
# 1466    0
# 1467    0
# 1468    0
# 1469    0
# Name: Attrition, Length: 1470, dtype: int64

# %%
from scipy.stats import skew
x.skew().sort_values(ascending=True)
# Out:
# BusinessTravel             -1.439006
# WorkLifeBalance            -0.552480
# JobInvolvement             -0.498419
# Gender                     -0.408665
# JobRole                    -0.357270
# JobSatisfaction            -0.329672
# EnvironmentSatisfaction    -0.321654
# RelationshipSatisfaction   -0.302828
# Education                  -0.289681
# MaritalStatus              -0.152175
# HourlyRate                 -0.032311
# DailyRate                  -0.003519
# StandardHours               0.000000
# EmployeeCount               0.000000
# Over18                      0.000000
# EmployeeNumber              0.016574
# MonthlyRate                 0.018578
# Department                  0.172231
# Age                         0.413286
# EducationField              0.550371
# TrainingTimesLastYear       0.553124
# PercentSalaryHike           0.821128
# YearsWithCurrManager        0.833451
# YearsInCurrentRole          0.917363
# DistanceFromHome            0.958118
# ...

# %%
from sklearn.preprocessing import power_transform
x_new=power_transform(x)
type(x_new)
# Out:
# numpy.ndarray

# %%
x=pd.DataFrame(x_new,columns=x.columns)
x
# Out:
#            Age  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0     0.522140        0.635468   0.759289    1.377454         -1.494085
# 1     1.276411       -1.392865  -1.334597   -0.472127          0.243416
# 2     0.102091        0.635468   1.340365   -0.472127         -1.031215
# 3    -0.353971       -1.392865   1.379936   -0.472127         -0.700347
# 4    -1.123755        0.635468  -0.453941   -0.472127         -1.031215
# ...        ...             ...        ...         ...               ...
# 1465 -0.008279       -1.392865   0.264672   -0.472127          1.407126
# 1466  0.316210        0.635468  -0.397219   -0.472127         -0.050827
# 1467 -1.123755        0.635468  -1.751713   -0.472127         -0.442291
# 1468  1.276411       -1.392865   0.583235    1.377454         -1.031215
# 1469 -0.236188        0.635468  -0.358845   -0.472127          0.243416
#
#       Education  EducationField  EmployeeCount  EmployeeNumber  \
# ...

# %%
x.shape
# Out:
# (1470, 34)

# %%
x.skew().sort_values(ascending=True)
# Out:
# BusinessTravel             -0.970506
# Gender                     -0.408665
# JobRole                    -0.319659
# EmployeeNumber             -0.288025
# JobSatisfaction            -0.212815
# EnvironmentSatisfaction    -0.205395
# DailyRate                  -0.196160
# RelationshipSatisfaction   -0.193634
# MonthlyRate                -0.184087
# MaritalStatus              -0.156911
# HourlyRate                 -0.106461
# Education                  -0.099881
# YearsWithCurrManager       -0.067565
# YearsInCurrentRole         -0.060849
# JobInvolvement             -0.020365
# WorkLifeBalance            -0.012286
# TotalWorkingYears          -0.010653
# YearsAtCompany             -0.008683
# EducationField             -0.008386
# Age                        -0.007603
# DistanceFromHome           -0.007468
# StandardHours               0.000000
# PerformanceRating           0.000000
# Over18                      0.000000
# MonthlyIncome               0.000000
# ...

# %%
nw=x.skew()
nw
# Out:
# Age                        -0.007603
# BusinessTravel             -0.970506
# DailyRate                  -0.196160
# Department                  0.013801
# DistanceFromHome           -0.007468
# Education                  -0.099881
# EducationField             -0.008386
# EmployeeCount               0.000000
# EmployeeNumber             -0.288025
# EnvironmentSatisfaction    -0.205395
# Gender                     -0.408665
# HourlyRate                 -0.106461
# JobInvolvement             -0.020365
# JobLevel                    0.103624
# JobRole                    -0.319659
# JobSatisfaction            -0.212815
# MaritalStatus              -0.156911
# MonthlyIncome               0.000000
# MonthlyRate                -0.184087
# NumCompaniesWorked          0.014814
# Over18                      0.000000
# OverTime                    0.964489
# PercentSalaryHike           0.116250
# PerformanceRating           0.000000
# RelationshipSatisfaction   -0.193634
# ...

# %% [markdown]
# so we have removed the skewness from the data.

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
def var_calc():
    vif=pd.DataFrame()
    vif['VIF Factor']=[variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
    vif['features']=x.columns
    print(vif)

# %%
var_calc()
# Out:
#     VIF Factor                  features
# 0     2.103317                       Age
# 1     1.012649            BusinessTravel
# 2     1.024090                 DailyRate
# 3     2.027102                Department
# 4     1.012839          DistanceFromHome
# 5     1.069849                 Education
# 6     1.027279            EducationField
# 7          NaN             EmployeeCount
# 8     1.024754            EmployeeNumber
# 9     1.020216   EnvironmentSatisfaction
# 10    1.020726                    Gender
# 11    1.022939                HourlyRate
# 12    1.020157            JobInvolvement
# 13    2.474155                  JobLevel
# 14    1.922594                   JobRole
# 15    1.023030           JobSatisfaction
# 16    2.305147             MaritalStatus
# 17         NaN             MonthlyIncome
# 18    1.020026               MonthlyRate
# 19    1.419115        NumCompaniesWorked
# 20         NaN                    Over18
# 21    1.028341                  OverTime
# ...

# %%
#training and testing of model
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=.20,random_state=153)

# %%
xtrain.shape
# Out:
# (1176, 34)

# %%
ytrain.shape
# Out:
# (1176,)

# %%
xtest.shape
# Out:
# (294, 34)

# %%
ytest.shape
# Out:
# (294,)

# %%
#APPLYING ML ALGORITHMS
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix,classification_report
#LogisticRegression
lg=LogisticRegression()
lg.fit(xtrain,ytrain)
predlg=lg.predict(xtest)
print(accuracy_score(ytest,predlg))
print(classification_report(ytest,predlg))
print(confusion_matrix(ytest,predlg))
# Out:
# 0.8979591836734694
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.94       255
#            1       0.70      0.41      0.52        39
#
#     accuracy                           0.90       294
#    macro avg       0.81      0.69      0.73       294
# weighted avg       0.89      0.90      0.89       294
#
# [[248   7]
#  [ 23  16]]

# %%
#RandomForestClassifier
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()
rfc.fit(xtrain,ytrain)
predrfc=rfc.predict(xtest)
print(accuracy_score(ytest,predrfc))
print(classification_report(ytest,predrfc))
print(confusion_matrix(ytest,predrfc))
# Out:
# 0.8877551020408163
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94       255
#            1       1.00      0.15      0.27        39
#
#     accuracy                           0.89       294
#    macro avg       0.94      0.58      0.60       294
# weighted avg       0.90      0.89      0.85       294
#
# [[255   0]
#  [ 33   6]]

# %%
#SUPPORT VECTOR CLASSIFIER
from sklearn.svm import SVC
svc=SVC()
svc.fit(xtrain,ytrain)
predsvc=svc.predict(xtest)
print(accuracy_score(ytest,predsvc))
print(classification_report(ytest,predsvc))
print(confusion_matrix(ytest,predsvc))
# Out:
# 0.9081632653061225
#               precision    recall  f1-score   support
#
#            0       0.91      1.00      0.95       255
#            1       0.93      0.33      0.49        39
#
#     accuracy                           0.91       294
#    macro avg       0.92      0.66      0.72       294
# weighted avg       0.91      0.91      0.89       294
#
# [[254   1]
#  [ 26  13]]

# %%
#GaussianNB
from sklearn.naive_bayes import GaussianNB
gnb=GaussianNB()
gnb.fit(xtrain,ytrain)
gnb.score(xtrain,ytrain)
predgnb=gnb.predict(xtest)
print(accuracy_score(ytest,predgnb))
print(confusion_matrix(ytest,predgnb))
print(classification_report(ytest,predgnb))
# Out:
# 0.8605442176870748
# [[232  23]
#  [ 18  21]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.91      0.92       255
#            1       0.48      0.54      0.51        39
#
#     accuracy                           0.86       294
#    macro avg       0.70      0.72      0.71       294
# weighted avg       0.87      0.86      0.86       294

# %%
from sklearn.tree import DecisionTreeClassifier
#DecisionTreeClassifier
dtc=DecisionTreeClassifier()
dtc.fit(xtrain,ytrain)
dtc.score(xtrain,ytrain)
preddtc=dtc.predict(xtest)
print(accuracy_score(ytest,preddtc))
print(confusion_matrix(ytest,preddtc))
print(classification_report(ytest,preddtc))
# Out:
# 0.7891156462585034
# [[216  39]
#  [ 23  16]]
#               precision    recall  f1-score   support
#
#            0       0.90      0.85      0.87       255
#            1       0.29      0.41      0.34        39
#
#     accuracy                           0.79       294
#    macro avg       0.60      0.63      0.61       294
# weighted avg       0.82      0.79      0.80       294

# %% [markdown]
# Among all the algorithms Logistic regression gives the highest accuracy of 89%. so we will go with Logistic Regression algorithm.

# %%
# CROSS VALIDATION
from sklearn.model_selection import cross_val_score
scr=cross_val_score(lg,x,y,cv=5)
print('cross validation score of logistic regression is',scr.mean())
# Out:
# cross validation score of logistic regression is 0.8721088435374149

# %%
scr2=cross_val_score(rfc,x,y,cv=5)
print('cross validation score of Random forest classifier is',scr2.mean())
# Out:
# cross validation score of Random forest classifier is 0.8564625850340135

# %%
scr3=cross_val_score(svc,x,y,cv=5)
print('cross validation score of Support vector classifier is',scr3.mean())
# Out:
# cross validation score of Support vector classifier is 0.8639455782312926

# %%
scr4=cross_val_score(gnb,x,y,cv=5)
print('cross validation score of Decision Tree classifier is',scr4.mean())
# Out:
# cross validation score of Decision Tree classifier is 0.8278911564625849

# %%
scr5=cross_val_score(rfc,x,y,cv=5)
print('cross validation score of Gaussian NB is',scr5.mean())
# Out:
# cross validation score of Gaussian NB is 0.8591836734693878

# %% [markdown]
# Logistic Regression is performing better among all so we will proceed with Logistic Regression.

# %%
# HYPERPARAMETER TUNING
RandomForestClassifier()
parameters={'max_features':["auto", "sqrt", "log2"],'max_depth':[4,5,6,7,8],'criterion':["gini", "entropy"]}

# %%
from sklearn.model_selection import GridSearchCV
gcv=GridSearchCV(RandomForestClassifier(),parameters,cv=5,scoring='accuracy')
gcv.fit(xtrain,ytrain)
gcv.best_params_ #printing the best parameters found by GridSearchCV
# Out:
# {'criterion': 'gini', 'max_depth': 8, 'max_features': 'log2'}

# %%
gcv_pred=gcv.best_estimator_.predict(xtest)
accuracy_score(ytest,gcv_pred)
# Out:
# 0.8877551020408163

# %%
#ROC AUC PLOT
from sklearn.metrics import plot_roc_curve
plot_roc_curve(gcv.best_estimator_,xtest,ytest)
plt.title('ROC-AUC Curve')
plt.show()

# %% [markdown]
# AUC score is 87%,so it is a good score.

# %%
#SAVING THE BEST MODEL
import joblib
joblib.dump(gcv.best_estimator_,'IBM_HR_Attrition.pk')
# Out:
# ['IBM_HR_Attrition.pk']
